# %%
from langchain_community.embeddings import OllamaEmbeddings

embeddings = OllamaEmbeddings(model="nomic-embed-text")

embeddings
# Out:
# OllamaEmbeddings(base_url='http://localhost:11434', model='nomic-embed-text', embed_instruction='passage: ', query_instruction='query: ', mirostat=None, mirostat_eta=None, mirostat_tau=None, num_ctx=None, num_gpu=None, num_thread=None, repeat_last_n=None, repeat_penalty=None, temperature=None, stop=None, tfs_z=None, top_k=None, top_p=None, show_progress=False, headers=None, model_kwargs=None)

# %%
r1=embeddings.embed_documents(
    [
        "Learn to build real-world AI agents, multi-agent workflows",
        "autonomous apps with LangGraph and LangChain"
    ]
)

r1
# Out:
# [[-0.5587500929832458,
#   1.257755160331726,
#   -3.549896717071533,
#   -0.16284559667110443,
#   1.4866604804992676,
#   -0.44200044870376587,
#   1.0986114740371704,
#   -0.6542418599128723,
#   0.21246694028377533,
#   -0.5257386565208435,
#   -0.4169215261936188,
#   0.7327579855918884,
#   1.7828490734100342,
#   0.6262190937995911,
#   0.16040505468845367,
#   0.5469100475311279,
#   0.129122793674469,
#   -0.40793871879577637,
#   0.026302432641386986,
#   0.3651053309440613,
#   0.2655755579471588,
#   -0.5080919861793518,
#   0.19974881410598755,
#   0.39062201976776123,
#   2.2261979579925537,
#   0.5107483863830566,
#   -0.5792180299758911,
#   -0.4955084025859833,
#   -1.1370545625686646,
#   -1.5622105598449707,
#   0.894564688205719,
#   -0.4085610508918762,
#   0.2108437418937683,
#   -0.39625269174575806,
#   -1.27792227268219,
#   -0.8922097086906433,
#   1.8748842477798462,
#   0.673560619354248,
#   -0.8127734065055847,
#   -0.08843200653791428,
# ...

# %%
r1[0]
# len(r1[0])
# Out:
# [-0.5587500929832458,
#  1.257755160331726,
#  -3.549896717071533,
#  -0.16284559667110443,
#  1.4866604804992676,
#  -0.44200044870376587,
#  1.0986114740371704,
#  -0.6542418599128723,
#  0.21246694028377533,
#  -0.5257386565208435,
#  -0.4169215261936188,
#  0.7327579855918884,
#  1.7828490734100342,
#  0.6262190937995911,
#  0.16040505468845367,
#  0.5469100475311279,
#  0.129122793674469,
#  -0.40793871879577637,
#  0.026302432641386986,
#  0.3651053309440613,
#  0.2655755579471588,
#  -0.5080919861793518,
#  0.19974881410598755,
#  0.39062201976776123,
#  2.2261979579925537,
#  0.5107483863830566,
#  -0.5792180299758911,
#  -0.4955084025859833,
#  -1.1370545625686646,
#  -1.5622105598449707,
#  0.894564688205719,
#  -0.4085610508918762,
#  0.2108437418937683,
#  -0.39625269174575806,
#  -1.27792227268219,
#  -0.8922097086906433,
#  1.8748842477798462,
#  0.673560619354248,
#  -0.8127734065055847,
#  -0.08843200653791428,
#  1.2975928783416748,
#  0.13855424523353577,
# ...

# %%
# Search Query

embeddings.embed_query("AI Agents")
# Out:
# [-0.38252341747283936,
#  0.8610521554946899,
#  -3.657717227935791,
#  0.5676136016845703,
#  2.065157651901245,
#  -0.40476810932159424,
#  -0.09633701294660568,
#  -0.19757235050201416,
#  1.1406420469284058,
#  1.1670000553131104,
#  -0.2798554003238678,
#  1.4296293258666992,
#  1.8908439874649048,
#  -0.2575496733188629,
#  0.7942256927490234,
#  -0.8918015360832214,
#  -0.41652122139930725,
#  0.0714777484536171,
#  0.27015647292137146,
#  -0.2545880377292633,
#  1.2071707248687744,
#  -0.8315446376800537,
#  0.49804770946502686,
#  -0.25443312525749207,
#  2.200155019760132,
#  -0.032026831060647964,
#  0.22265584766864777,
#  0.1917637139558792,
#  -0.0019856251310557127,
#  -0.7989648580551147,
#  -0.38890013098716736,
#  0.45195239782333374,
#  -0.17785246670246124,
#  -0.7668207883834839,
#  0.13710953295230865,
#  -0.6582627296447754,
#  1.502828598022461,
#  1.780509114265442,
#  -0.21751902997493744,
#  0.11381717771291733,
#  -0.12490611523389816,
# ...

# %%
from langchain_community.embeddings import OllamaEmbeddings
from langchain_community.vectorstores import Chroma

# Create embeddings
embeddings = OllamaEmbeddings(model="nomic-embed-text")

# Your documents
documents = [
    "Learn to build real-world AI agents, multi-agent workflows",
    "autonomous apps with LangGraph and LangChain"
    "Gone are the days of citing only print resources and web pages. In 2025, podcasts are an ever-growing source of unique content with valuable (and citable) information."
]

# Create ChromaDB and add documents (ONE LINE!)
vectordb = Chroma.from_texts(
    texts=documents,
    embedding=embeddings,
    persist_directory="./my_chroma_db"  # Saves to folder
)

print("✅ Documents added to ChromaDB!")
# Out:
# ✅ Documents added to ChromaDB!

# %%
# Search for similar documents
results = vectordb.similarity_search("AI Agents", k=2)

print(results)
# Out:
# [Document(metadata={}, page_content='Learn to build real-world AI agents, multi-agent workflows'), Document(metadata={}, page_content='autonomous apps with LangGraph and LangChain')]
